# %% [markdown]
# UNIVERSITAT WIEN ¨
# CSLEARN - EDUCATIONAL TECHNOLOGIES
# Natural Language Processing
# Exercise Sheet 1
# Language Processing and Python

# %%
import nltk
#nltk.download()
from nltk.book import *
import matplotlib.pyplot as plt
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# Exercise 1
# How many words are there in text2 from nltk.book? How many distinct words are
# there? Calculate the lexical diversity.

# %%
print("words: ", len(text2))
print("distinct words: ", len(set(text2)))
print("lexical diversity: ", len(set(text2))/len(text2) )
# Out:
# words:  141576
# distinct words:  6833
# lexical diversity:  0.04826383002768831

# %% [markdown]
# Exercise 2
# Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor,
# Marianne, Edward, and Willoughby. What can you observe about the different roles
# played by the males and females in this novel? Can you identify the couples?

# %%
# %matplotlib inline
plt.figure(figsize=(20, 6))  # the size you want
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# - Elinor and Marianne are main characters. Willoughby and Edward are secondary characters
# - Elinor and Edward are a couple. Marianne and willoughby are a couple.

# %% [markdown]
# Exercise 3
# Find the collocations in text6.

# %%
text6.collocation_list()
# Out:
# ['BLACK KNIGHT',
#  'clop clop',
#  'HEAD KNIGHT',
#  'mumble mumble',
#  'Holy Grail',
#  'squeak squeak',
#  'FRENCH GUARD',
#  'saw saw',
#  'Sir Robin',
#  'Run away',
#  'CARTOON CHARACTER',
#  'King Arthur',
#  'Iesu domine',
#  'Pie Iesu',
#  'DEAD PERSON',
#  'Round Table',
#  'clap clap',
#  'OLD MAN',
#  'dramatic chord',
#  'dona eis']

# %% [markdown]
# Exercise 4
# Use only the index() function to find all the indexes of the word “sunset” in text9.

# %%
ind_old=0
text=text9
while True:
    try:
        ind_total=text.index("sunset")+ind_old+1
        print(ind_total)
    except:
        break
    ind_old=ind_total
    text=text9[ind_total:]
# Out:
# 630
# 643
# 1433
# 1651
# 13336
# 13382
# 16314
# 27015
# 49341
# 52093
# 60858
# 60863
# 64722
# 64737

# %% [markdown]
# Exercise 5
# What is the difference between the following two lines? Calculate the two values:
# len(sorted(set(w.lower() for w in text1)))
# len(sorted(w.lower() for w in set(text1)))

# %%
first=len(sorted(set(w.lower() for w in text1)))
second=len(sorted(w.lower() for w in set(text1)))
print(first,second)
# Out:
# 17231 19317

# %% [markdown]
# - first is a count of all unique words in text1 without being case sensitive
# - second is a count of all case sensitive unique words in text1

# %% [markdown]
# Exercise 6
# Write the slice expression that extracts the last two words of text2.

# %%
text[-2:]
# Out:
# ['girl', '.']

# %% [markdown]
# Exercise 7
# Find all the four-letter words in text6. With the help of a frequency distribution
# (FreqDist), show these words in decreasing order of frequency.

# %%
w_four = [w for w in text6 if len(w) == 4]
print(len(w_four), " words")
fdist = FreqDist(w_four)
print(fdist.most_common())
# Out:
# 2298  words
# ...

# %%
plt.figure(figsize=(20, 20))  # the size you want
fdist.plot(50, cumulative=True)
